# %% [markdown]
# ## Import necessary librarys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load and processing datasets

# %%
# We load the data using the Pandas library and see the first 5 of them
dataset = pd.read_excel("./data/DryBeanDataset/Dry_Bean_Dataset.xlsx")
dataset.head()
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
# 2  29380    624.110       212.826130       175.931143      1.209713
# 3  30008    645.884       210.557999       182.516516      1.153638
# 4  30140    620.134       201.847882       190.279279      1.060798
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272750  0.783968  0.984986   0.887034
# 2      0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3      0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4      0.333680       30417     195.896503  0.773098  0.990893   0.984877
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# ...

# %%
sns.set_style("white")
dataset.hist(bins=30, figsize=(17, 12))
plt.show()

# %%
# We see a summary of the dataset and the information of its columns
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
# ...

# %%
# We check whether we have empty data or not
dataset.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
# see a summary description of the data
dataset.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.303633       175.848170
# 50%     44652.000000    794.941000       296.883367       192.431733
# 75%     61332.000000    977.213000       376.495012       217.031741
# max    254616.000000   1985.370000       738.860153       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     253.064220      0.749733
# std        0.246678      0.092002   29774.915817      59.177120      0.049086
# ...

# %%
# check the number of classes
dataset["Class"].nunique()
# Out:
# 7

# %%
# value of each class
dataset["Class"].value_counts()
# Out:
# Class
# DERMASON    3546
# SIRA        2636
# SEKER       2027
# HOROZ       1928
# CALI        1630
# BARBUNYA    1322
# BOMBAY       522
# Name: count, dtype: int64

# %% [markdown]
# We plot data based on MajorAxisLength and MinorAxisLength and separation based on classes

# %% [markdown]
# Here we can see that the BOMBAY class has more dimensions than the classes

# %% [markdown]
# In this code snippet, we utilize Matplotlib library to create a scatter plot. We plot the 'MajorAxisLength' on the x-axis and the 'MinorAxisLength' on the y-axis. Each data point represents an observation in the dataset. The 'MajorAxisLength' and 'MinorAxisLength' are two different features of the dataset. The plt.scatter() function is used to create the scatter plot, and plt.grid(True) adds grid lines to the plot for better visualization. Finally, plt.show() displays the plot.

# %% [markdown]
# Analysis:
#
# By visualizing the relationship between 'MajorAxisLength' and 'MinorAxisLength' using the scatter plot, we can observe if there exists any correlation or pattern between these two features. If the data points appear to follow a certain trend (e.g., linear or non-linear), it indicates a relationship between the two features. Conversely, if the data points are scattered randomly, it suggests that there might not be a strong relationship between the features. Additionally, outliers or clusters of data points can also be identified through this visualization, providing insights into the distribution of the data.

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(
    data=dataset,
    x="MajorAxisLength",
    y="MinorAxisLength",
    hue="Class",
)
plt.title(
    "Major-Mnore lenghth per Class", fontdict={"size": 12, "weight": "bold"}, loc="left"
)
plt.xlabel(loc="left", fontdict={"size": 8, "weight": "bold"}, xlabel="MajorAxisLength")
plt.ylabel(
    loc="bottom", fontdict={"size": 8, "weight": "bold"}, ylabel="MinorAxisLength"
)
plt.gca().spines[["top", "right"]].set_visible(False)

# %%
# Which bean has the largest perimeter?
Perimeter = (
    dataset.groupby("Class")["Perimeter"]
    .agg("mean")
    .reset_index()
    .sort_values(by="Perimeter", ascending=False)
)
Perimeter
# Out:
#       Class    Perimeter
# 1    BOMBAY  1585.619079
# 2      CALI  1057.634282
# 0  BARBUNYA  1046.105764
# 4     HOROZ   919.859676
# 6      SIRA   796.418737
# 5     SEKER   727.672440
# 3  DERMASON   665.209536

# %%
plt.figure(figsize=(9, 6))
sns.barplot(data=Perimeter, x="Class", y="Perimeter", palette="viridis", width=0.5)
plt.title("largest perimeter", loc="left", fontdict={"size": 12, "weight": "bold"})
plt.xlabel("Class", loc="left", fontdict={"weight": "bold"})
plt.ylabel("Perimeter", loc="bottom", fontdict={"weight": "bold"})
plt.gca().spines[["top", "right"]].set_visible(False)

# %%
# check the largest diameter
EquivDiameter = (
    dataset.groupby("Class")["EquivDiameter"]
    .agg("mean")
    .reset_index()
    .sort_values(by="EquivDiameter", ascending=False)
)
EquivDiameter
# Out:
#       Class  EquivDiameter
# 1    BOMBAY     468.941426
# 2      CALI     309.535280
# 0  BARBUNYA     297.311018
# 4     HOROZ     260.730715
# 6      SIRA     238.335316
# 5     SEKER     224.948441
# 3  DERMASON     201.683813

# %%
plt.figure(figsize=(9, 6))
sns.barplot(
    data=EquivDiameter, x="Class", y="EquivDiameter", palette="viridis", width=0.5
)
plt.title("largest EquivDiameter", loc="left", fontdict={"size": 12, "weight": "bold"})
plt.xlabel("Class", loc="left", fontdict={"weight": "bold"})
plt.ylabel("EquivDiameter", loc="bottom", fontdict={"weight": "bold"})
plt.gca().spines[["top", "right"]].set_visible(False)

# %%
# Which bean has more Solidity?

Solidity = (
    dataset.groupby("Class")["Solidity"]
    .agg("mean")
    .reset_index()
    .sort_values(by="Solidity", ascending=False)
)
Solidity
# Out:
#       Class  Solidity
# 5     SEKER  0.990351
# 3  DERMASON  0.988226
# 6      SIRA  0.987971
# 1    BOMBAY  0.986902
# 4     HOROZ  0.985480
# 2      CALI  0.985021
# 0  BARBUNYA  0.982804

# %%
plt.figure(figsize=(9, 6))
sns.set_style("whitegrid")
sns.scatterplot(data=Solidity, x="Class", y="Solidity", hue="Class")
plt.title("More Solidity", loc="left", fontdict={"size": 12, "weight": "bold"})
plt.xlabel("Class", loc="left", fontdict={"weight": "bold"})
plt.ylabel("Solidity", loc="bottom", fontdict={"weight": "bold"})
plt.gca().spines[["top", "right"]].set_visible(False)

# %% [markdown]
# calculate the correlation between the features

# %%
# First, we convert the classes into numerical data
dataset["class_int"] = np.repeat(np.arange(1, 8), len(dataset["Class"]) // 7 + 1)[
    : len(dataset["Class"])
]

dataset[["Class", "class_int"]]
# Out:
#           Class  class_int
# 0         SEKER          1
# 1         SEKER          1
# 2         SEKER          1
# 3         SEKER          1
# 4         SEKER          1
# ...         ...        ...
# 13606  DERMASON          7
# 13607  DERMASON          7
# 13608  DERMASON          7
# 13609  DERMASON          7
# 13610  DERMASON          7
#
# [13611 rows x 2 columns]

# %%
dataset["shape_ratio"] = (
    dataset["ShapeFactor1"]
    + dataset["ShapeFactor2"]
    + dataset["ShapeFactor3"]
    + dataset["ShapeFactor4"]
) / 4

# %%
dataset["Mean_Area_Perimeter"] = (dataset["Area"] + dataset["Perimeter"]) / 2

# %%
dataset["Log_Area"] = np.log(dataset["Area"])

# %%
dataset["major-minor_ratio"] = dataset["MajorAxisLength"] + dataset["MinorAxisLength"]

# %%
dataset_corr = dataset.select_dtypes(np.number)
dataset_corr
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  ...  \
# ...

# %%
# Find the relationship between any data
dataset_corr.corr()["class_int"].sort_values().reset_index()
# Out:
#                   index  class_int
# 0       MinorAxisLength  -0.535584
# 1              Log_Area  -0.483003
# 2         EquivDiameter  -0.449464
# 3             Perimeter  -0.438987
# 4     major-minor_ratio  -0.431937
# 5   Mean_Area_Perimeter  -0.404033
# 6            ConvexArea  -0.403873
# 7                  Area  -0.403680
# 8       MajorAxisLength  -0.351158
# 9          ShapeFactor3  -0.223266
# 10          shape_ratio  -0.207235
# 11          Compactness  -0.200990
# 12               Extent  -0.104922
# 13         ShapeFactor4   0.060174
# 14             Solidity   0.076449
# 15         ShapeFactor2   0.087986
# 16            roundness   0.109633
# 17         AspectRation   0.140459
# 18         Eccentricity   0.306023
# 19         ShapeFactor1   0.627462
# 20            class_int   1.000000

# %% [markdown]
# Explanation:
#
# In this code snippet, we utilize Matplotlib library to create a bar plot. The 'class_int' variable represents the class or category of each data point, and the 'Area' variable represents the corresponding area value for each class. Each bar in the plot represents the average or total area value for a specific class. The plt.bar() function is used to create the bar plot, where the first argument specifies the x-values (class labels) and the second argument specifies the y-values (area values). The plt.title(), plt.xlabel(), and plt.ylabel() functions are used to add a title, x-axis label, and y-axis label to the plot, respectively. Finally, plt.grid(True) adds grid lines to the plot for better visualization, and plt.show() displays the plot.

# %% [markdown]
# Analysis:
#
# By visualizing the distribution of the 'Area' variable across different classes using the bar plot, we can analyze how the area varies across different categories or classes. We can identify which class has the highest or lowest average area, as well as any variations or patterns in area distribution among different classes. This visualization helps in understanding the distribution of the 'Area' variable and its relationship with the classes in the dataset. It also provides insights into any potential differences or similarities in area values across different categories.

# %%
plt.figure(figsize=(8, 6))
plt.bar(dataset["class_int"], dataset["Area"], color="gray")
plt.title("Bar Plot of Class vs. Area", loc="left")
plt.xlabel("Class", loc="left")
plt.ylabel("Area", loc="bottom")
plt.grid(True)
plt.show()

# %% [markdown]
# Explanation:
#
# In this code snippet, we utilize the Seaborn library along with Matplotlib to create a box plot. The box plot visualizes the distribution of the 'Perimeter' variable across different classes ('class_int'). Each box in the plot represents the interquartile range (IQR) of the data, with the median indicated by the line inside the box. The whiskers extending from the box show the range of the data, excluding outliers. Outliers are plotted individually as points beyond the whiskers. The sns.boxplot() function is used to create the box plot, where the 'class_int' variable is mapped to the x-axis and the 'Perimeter' variable is mapped to the y-axis. The plt.title(), plt.xlabel(), and plt.ylabel() functions are used to add a title, x-axis label, and y-axis label to the plot, respectively. Finally, plt.grid(True) adds grid lines to the plot for better visualization, and plt.show() displays the plot.

# %% [markdown]
# Analysis:
#
# By visualizing the distribution of the 'Perimeter' variable across different classes using the box plot, we can analyze the central tendency, spread, and variability of the perimeter values within each class. The box plot allows us to compare the distributions of perimeter values among different classes and identify any variations or outliers. We can determine if there are significant differences in the perimeter values between classes and if any class has a wider or narrower distribution of perimeter values compared to others. This visualization helps in understanding the distributional characteristics of the 'Perimeter' variable and its relationship with the classes in the dataset.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="class_int", y="Perimeter", data=dataset)
plt.title("Box Plot of Perimeter for Each Class", loc="left")
plt.xlabel("Class", loc="left")
plt.ylabel("Perimeter", loc="bottom")
plt.grid(True)
plt.show()

# %% [markdown]
# Explanation:
#
# In this code snippet, we utilize Matplotlib library to create a histogram plot. The histogram represents the frequency distribution of the 'Area' variable in the dataset. The 'Area' variable contains numerical data representing the area of objects or entities. The histogram divides the range of 'Area' values into bins (in this case, 30 bins), and each bin represents a specific range of area values. The height of each bar in the histogram indicates the frequency (or count) of data points falling within that bin. The plt.hist() function is used to create the histogram plot, where the first argument specifies the data to be plotted, the bins parameter determines the number of bins, and color and alpha parameters specify the color and transparency of the bars, respectively. The plt.title(), plt.xlabel(), and plt.ylabel() functions are used to add a title, x-axis label, and y-axis label to the plot, respectively. Finally, plt.grid(True) adds grid lines to the plot for better visualization, and plt.show() displays the plot.

# %% [markdown]
# Analysis:
#
# By visualizing the histogram of the 'Area' variable, we can analyze the distribution of area values in the dataset. The histogram helps in understanding the central tendency, spread, and variability of the area values. We can observe the shape of the distribution, whether it is symmetric, skewed to the left or right, or multimodal. Additionally, the histogram allows us to identify any outliers or unusual patterns in the data. Analyzing the histogram provides insights into the typical range of area values and their frequency of occurrence in the dataset, which is valuable for understanding the characteristics of the 'Area' variable and its distribution within the dataset.

# %%
plt.figure(figsize=(8, 6))
plt.hist(dataset["Area"], bins=30, color="blue", alpha=0.7)
plt.title("Histogram of Area", loc="left")
plt.xlabel("Area", loc="left")
plt.ylabel("Frequency", loc="bottom")
plt.grid(True)
plt.show()

# %% [markdown]
# Explanation:
#
# In this code snippet, we create a radar plot to visualize the values of multiple features for a specific sample. Radar plots, also known as spider or star plots, are useful for comparing the values of multiple variables across different categories or in this case, features. Each feature is represented by a spoke emanating from the center of the plot, and the value of the feature determines the distance of the point along the corresponding spoke.

# %% [markdown]
# Analysis:
#
# By visualizing the radar plot of the sample features, we can analyze the relative magnitudes of each feature for the given sample. The distance of each point from the center of the plot represents the magnitude of the corresponding feature. We can compare the values of different features and observe any patterns or discrepancies among them. This visualization helps in understanding the distribution of feature values and identifying any outliers or unusual patterns in the data. Additionally, it provides insights into the relative importance or contribution of each feature to the overall sample. Overall, the radar plot aids in exploring the multivariate relationships among the features and gaining a holistic understanding of the sample characteristics.

# %%
features = ["Area", "Perimeter", "MajorAxisLength", "MinorAxisLength"]


sample_index = 0
values = dataset.loc[sample_index, features].values.reshape(1, -1)


angles = np.linspace(0, 2 * np.pi, len(features), endpoint=False).tolist()


values = np.concatenate((values, values[:, [0]]), axis=1)
angles += angles[:1]


fig, ax = plt.subplots(figsize=(8, 6), subplot_kw=dict(polar=True))
ax.fill(angles, values.flatten(), color="red", alpha=0.25)
ax.plot(angles, values.flatten(), color="red", linewidth=2)
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(features)
plt.title("Radar Plot of Sample Features")
plt.show()

# %% [markdown]
# # Preprocessing Data

# %%
# Import necessary librarys for preprocessing

from sklearn.preprocessing import StandardScaler, FunctionTransformer, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics.pairwise import rbf_kernel

# %% [markdown]
# create a pipeline for the heavy_tail data

# %%
heavy_tail_pipe = Pipeline(
    [
        ("log", FunctionTransformer(np.log, feature_names_out="one-to-one")),
        ("scale", StandardScaler()),
    ]
)
heavy_tail_pipe
# Out:
# Pipeline(steps=[('log',
#                  FunctionTransformer(feature_names_out='one-to-one',
#                                      func=<ufunc 'log'>)),
#                 ('scale', StandardScaler())])

# %% [markdown]
# create a new column for the shape_ratio

# %%
# Divide the data into the train and the test
target = dataset["Class"]
dataset = dataset.drop("Class", axis=1)
target.shape, dataset.shape
# Out:
# ((13611,), (13611, 21))

# %% [markdown]
# split dataset into train and test

# %%
xtrain, xtest, ytrain, ytest = train_test_split(
    dataset, target, test_size=0.2, random_state=42, shuffle=True
)

# %%
# Checking that in each round of test data and train classes are distributed fairly

print(f"Xtrain no Classes:{np.count_nonzero(np.unique(xtrain['class_int']))}")
print(f"Xtest no Classes:{np.count_nonzero(np.unique(xtest['class_int']))}")
# Out:
# Xtrain no Classes:7
# Xtest no Classes:7

# %% [markdown]
# drop the class_int column

# %%
xtrain = xtrain.drop("class_int", axis=1)
xtest = xtest.drop("class_int", axis=1)

# %%
# put all processing factors into a variable named all_transform

all_transform = ColumnTransformer(
    [
        (
            "heavy",
            heavy_tail_pipe,
            [
                "Area",
                "Perimeter",
                "MajorAxisLength",
                "MinorAxisLength",
                "ConvexArea",
                "EquivDiameter",
            ],
        ),
    ],
    remainder="passthrough",
)
all_transform
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('heavy',
#                                  Pipeline(steps=[('log',
#                                                   FunctionTransformer(feature_names_out='one-to-one',
#                                                                       func=<ufunc 'log'>)),
#                                                  ('scale', StandardScaler())]),
#                                  ['Area', 'Perimeter', 'MajorAxisLength',
#                                   'MinorAxisLength', 'ConvexArea',
#                                   'EquivDiameter'])])

# %%
# do all transform with train_transform command
train_transform = all_transform.fit_transform(xtrain)
test_transform = all_transform.transform(xtest)

# %%
all_transform.get_feature_names_out()
# Out:
# array(['heavy__Area', 'heavy__Perimeter', 'heavy__MajorAxisLength',
#        'heavy__MinorAxisLength', 'heavy__ConvexArea',
#        'heavy__EquivDiameter', 'remainder__AspectRation',
#        'remainder__Eccentricity', 'remainder__Extent',
#        'remainder__Solidity', 'remainder__roundness',
#        'remainder__Compactness', 'remainder__ShapeFactor1',
#        'remainder__ShapeFactor2', 'remainder__ShapeFactor3',
#        'remainder__ShapeFactor4', 'remainder__shape_ratio',
#        'remainder__Mean_Area_Perimeter', 'remainder__Log_Area',
#        'remainder__major-minor_ratio'], dtype=object)

# %% [markdown]
# plot data after transformation

# %%
sns.set_style("white")
all_df = pd.DataFrame(train_transform, columns=all_transform.get_feature_names_out())
all_df.hist(bins=30, figsize=(17, 12))
plt.show()

# %% [markdown]
# # Import ML models from sklearn

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Import GridSearchCV for find best hyperparameters and models
from sklearn.model_selection import GridSearchCV, cross_val_score


from sklearn.metrics import (
    ConfusionMatrixDisplay,
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
)

from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Find the best model using the GridSearchCV command

# %% [markdown]
# we use the GridSearchCV and all parameters for the best model

# %%
pipe = Pipeline([("classifire", None)])

param_grids = [
    {
        "classifire": [SVC()],
    },
    {
        "classifire": [KNeighborsClassifier()],
        "classifire__n_neighbors": [1, 2, 3, 4, 5, 6],
        "classifire__n_jobs": [5, 10, 15],
    },
    {
        "classifire": [RandomForestClassifier()],
        "classifire__n_estimators": [300, 400],
        "classifire__max_depth": [20, 25],
        "classifire__n_jobs": [3, 5, 7],
    },
]

# %%
gs = GridSearchCV(
    pipe,
    param_grid=param_grids,
    cv=5,
    verbose=1,
    scoring={"accuracy": "accuracy"},
    refit="accuracy",
)
gs
# Out:
# GridSearchCV(cv=5, estimator=Pipeline(steps=[('classifire', None)]),
#              param_grid=[{'classifire': [SVC()]},
#                          {'classifire': [KNeighborsClassifier()],
#                           'classifire__n_jobs': [5, 10, 15],
#                           'classifire__n_neighbors': [1, 2, 3, 4, 5, 6]},
#                          {'classifire': [RandomForestClassifier()],
#                           'classifire__max_depth': [20, 25],
#                           'classifire__n_estimators': [300, 400],
#                           'classifire__n_jobs': [3, 5, 7]}],
#              refit='accuracy', scoring={'accuracy': 'accuracy'}, verbose=1)

# %%
# fit the model
gs.fit(train_transform, ytrain)
# Out:
# Fitting 5 folds for each of 31 candidates, totalling 155 fits
# GridSearchCV(cv=5, estimator=Pipeline(steps=[('classifire', None)]),
#              param_grid=[{'classifire': [SVC()]},
#                          {'classifire': [KNeighborsClassifier()],
#                           'classifire__n_jobs': [5, 10, 15],
#                           'classifire__n_neighbors': [1, 2, 3, 4, 5, 6]},
#                          {'classifire': [RandomForestClassifier()],
#                           'classifire__max_depth': [20, 25],
#                           'classifire__n_estimators': [300, 400],
#                           'classifire__n_jobs': [3, 5, 7]}],
#              refit='accuracy', scoring={'accuracy': 'accuracy'}, verbose=1)

# %%
# best estimator
gs.best_estimator_
model = gs.best_estimator_
model
# Out:
# Pipeline(steps=[('classifire',
#                  RandomForestClassifier(max_depth=20, n_estimators=300,
#                                         n_jobs=5))])

# %%
# best parameters for the best estimator
gs.best_params_
# Out:
# {'classifire': RandomForestClassifier(),
#  'classifire__max_depth': 20,
#  'classifire__n_estimators': 300,
#  'classifire__n_jobs': 5}

# %%
# best score for the best estimator
gs.best_score_
# Out:
# 0.9211057415091324

# %%
# predict model with test data
gs_pred = model.predict(test_transform)

# %%
# model cross val scoring after 50 cv
gs_scores = cross_val_score(model, train_transform, ytrain, cv=50, scoring="accuracy")

# %%
np.mean(gs_scores) * 100
# Out:
# 92.20179258445019

# %% [markdown]
#  use classification_report to evaluate the model

# %%
# model classification_report
print(classification_report(ytest, gs_pred))
# Out:
#               precision    recall  f1-score   support
#
#     BARBUNYA       0.92      0.89      0.91       261
#       BOMBAY       1.00      1.00      1.00       117
#         CALI       0.92      0.93      0.93       317
#     DERMASON       0.90      0.92      0.91       671
#        HOROZ       0.97      0.96      0.96       408
#        SEKER       0.96      0.94      0.95       413
#         SIRA       0.87      0.88      0.88       536
#
#     accuracy                           0.92      2723
#    macro avg       0.94      0.93      0.93      2723
# weighted avg       0.92      0.92      0.92      2723

# %%
dataset_ = pd.read_excel("./data/DryBeanDataset/Dry_Bean_Dataset.xlsx")

# %%
import warnings
from sklearn.preprocessing import LabelEncoder


warnings.filterwarnings("ignore", category=UserWarning)


le = LabelEncoder()

yy_train = le.fit_transform(ytest)


gs_prob = model.predict_proba(xtest)


fpr = {}


tpr = {}


roc_auc = {}


num_classes = 7


y_test_2d = np.zeros((len(yy_train), num_classes))


y_test_2d[np.arange(len(yy_train)), yy_train] = 1


for i in range(num_classes):

    fpr[i], tpr[i], _ = roc_curve(y_test_2d[:, i], gs_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))


mean_tpr = np.zeros_like(all_fpr)


for i in range(num_classes):

    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])


mean_tpr /= num_classes
roc_auc["macro"] = auc(all_fpr, mean_tpr)


class_ = list(dataset_["Class"].unique())


for i in range(num_classes):

    plt.plot(fpr[i], tpr[i], label=f"Class {class_[i]} (AUC = {roc_auc[i]:.2f})")

    plt.plot([0, 1], [0, 1], linestyle="--", color="r", label="Random")

    plt.xlabel("False Positive Rate")

    plt.ylabel("True Positive Rate")

    plt.title("ROC Curve")

    plt.legend()

    plt.show()

# %% [markdown]
# Here we can see that the Sira class has the lowest accuracy and the highest error among other classes, and this can be due to its similarity with other classes close to it.

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(15, 8))
plt.plot(gs_scores)
plt.title(
    "RandomForestClassifier model accuracy after 50 time croos validaton",
    loc="left",
    fontdict={"weight": "bold"},
)
plt.ylabel("accuracy", loc="bottom", fontdict={"weight": "bold"})
plt.xlabel("Cv", loc="left", fontdict={"weight": "bold"})
plt.gca().spines[["top", "right"]].set_visible(False)
plt.show()

# %%
# confusion matrix
sns.set_style("white")
cm = confusion_matrix(ytest, gs_pred)

plt.figure(figsize=(13, 9))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=gs.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# In the drawn confusion_matrix, I see that the biggest error is between prediction for two classes SIRA and DERAMASON
#
# This happened because of the similarity of the two classes

# %%
ord = OrdinalEncoder()
ytrain_xgb = ord.fit_transform(ytrain.to_numpy().reshape(-1, 1))
ytest_xgb = ord.transform(ytest.to_numpy().reshape(-1, 1))

# %%
import xgboost as xgb

xgboost_ml = xgb.XGBClassifier(random_state=42)
xgboost_ml.fit(train_transform, ytrain_xgb)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %% [markdown]
# By performing cross_val_score and the number of cv 5, we find the average accuracy of the model

# %%
xgs_scores = cross_val_score(
    xgboost_ml, train_transform, ytrain_xgb, cv=50, scoring="accuracy"
)
xgs_scores
# Out:
# array([0.9266055 , 0.9266055 , 0.92201835, 0.91743119, 0.94036697,
#        0.92201835, 0.90366972, 0.89908257, 0.9266055 , 0.97247706,
#        0.97247706, 0.94036697, 0.93577982, 0.89908257, 0.94495413,
#        0.9266055 , 0.92201835, 0.9266055 , 0.93119266, 0.93577982,
#        0.94495413, 0.93577982, 0.9266055 , 0.93577982, 0.88990826,
#        0.92201835, 0.91743119, 0.90366972, 0.91743119, 0.9587156 ,
#        0.94495413, 0.94495413, 0.9266055 , 0.93119266, 0.94954128,
#        0.94495413, 0.90366972, 0.91284404, 0.89400922, 0.93087558,
#        0.92626728, 0.95391705, 0.89400922, 0.9124424 , 0.94930876,
#        0.93087558, 0.93548387, 0.94470046, 0.90322581, 0.9124424 ])

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(15, 8))
plt.plot(xgs_scores)
plt.title(
    "xgboost model accuracy after 50 time croos validaton",
    loc="left",
    fontdict={"weight": "bold"},
)
plt.ylabel("accuracy", loc="bottom", fontdict={"weight": "bold"})
plt.xlabel("Cv", loc="left", fontdict={"weight": "bold"})
plt.gca().spines[["top", "right"]].set_visible(False)
plt.show()

# %%
xgb_pred = xgboost_ml.predict(test_transform, ytest_xgb.all())
score = xgboost_ml.score(test_transform, ytest_xgb)

print(f"xgboost_ml score : {score*100:.2f}%")
# Out:
# xgboost_ml score : 92.80%

# %%
# confusion matrix
sns.set_style("white")
cm_g = confusion_matrix(ytest_xgb, xgb_pred)

plt.figure(figsize=(12, 8))
disp = ConfusionMatrixDisplay(confusion_matrix=cm_g, display_labels=xgboost_ml.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("XGB Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
import warnings
from sklearn.preprocessing import LabelEncoder


warnings.filterwarnings("ignore", category=UserWarning)


le = LabelEncoder()

yy_train = le.fit_transform(ytest)


gs_prob = xgboost_ml.predict_proba(xtest)


fpr = {}


tpr = {}


roc_auc = {}


num_classes = 7


y_test_2d = np.zeros((len(yy_train), num_classes))


y_test_2d[np.arange(len(yy_train)), yy_train] = 1


for i in range(num_classes):

    fpr[i], tpr[i], _ = roc_curve(y_test_2d[:, i], gs_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])


all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))


mean_tpr = np.zeros_like(all_fpr)


for i in range(num_classes):

    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])


mean_tpr /= num_classes
roc_auc["macro"] = auc(all_fpr, mean_tpr)


class_ = list(dataset_["Class"].unique())


for i in range(num_classes):

    plt.plot(fpr[i], tpr[i], label=f"Class {class_[i]} (AUC = {roc_auc[i]:.2f})")

    plt.plot([0, 1], [0, 1], linestyle="--", color="r", label="Random")

    plt.xlabel("False Positive Rate")

    plt.ylabel("True Positive Rate")

    plt.title("ROC Curve")

    plt.legend()

    plt.show()

# %% [markdown]
# # Find the best model using the GridSearchCV and the results

# %%
print("XGBClassifier")
print(f"{score*100:.2f}%")
print("-------------")
print("RandomForestClassifier")
print(f"{gs.best_score_*100:.2f}")
# Out:
# XGBClassifier
# 92.80%
# -------------
# RandomForestClassifier
# 92.11

# %% [markdown]
# Finally, we choose the XGBClassifier model here because of its higher accuracy and faster speed

# %% [markdown]
# save model for use

# %%
import joblib

joblib.dump(xgboost_ml, "xgboost_model")
# Out:
# ['xgboost_model']
